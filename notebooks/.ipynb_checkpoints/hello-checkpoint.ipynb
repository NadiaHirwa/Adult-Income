# %% [raw]
# ---
# title: "Quarto Basics"
# author:
#   - name: "Socrates Waka Onyando"
#     affiliation: "Data Science Educator"
#   - name: "Jane Doe"
#     affiliation: "AI Researcher"
# format: revealjs
# date: "2025-06-05"
# format:
#   html:
#     code-fold: true
# jupyter: python3
# ---

# %% [markdown]
# ## Polar Axis
#
# For a demonstration of a line plot on a polar axis, see @fig-polar.

# %%
#| label: fig-polar
#| fig-cap: "A line plot on polar axis" 
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Sample dataset
tips = sns.load_dataset("tips")

# Scatterplot with Seaborn
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="day")
plt.title("Total Bill vs Tip by Day")
plt.show()

# %% [markdown]
# ## Visualization with Seaborn

# %%
import seaborn as sns
import pandas as pd

# Sample dataset
tips = sns.load_dataset("tips")

# Scatterplot with Seaborn
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="day")
plt.title("Total Bill vs Tip by Day")
plt.show()

# %% [markdown]
# ## Interactive Visualization with Plotly

# %%
import plotly.express as px

df = px.data.iris()

fig = px.scatter(df, x="sepal_width", y="sepal_length",
                 color="species", size="petal_length",
                 title="Interactive Iris Scatter Plot")
fig.show()
# Out:
# <div>                            <div id="03fdbc95-0289-41ca-a8c6-299fc6be1fdf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03fdbc95-0289-41ca-a8c6-299fc6be1fdf")) {                    Plotly.newPlot(                        "03fdbc95-0289-41ca-a8c6-299fc6be1fdf",                        [{"hovertemplate":"species=setosa\u003cbr\u003esepal_width=%{x}\u003cbr\u003esepal_length=%{y}\u003cbr\u003epetal_length=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"setosa","marker":{"color":"#636efa","size":[1.4,1.4,1.3,1.5,1.4,1.7,1.4,1.5,1.4,1.5,1.5,1.6,1.4,1.1,1.2,1.5,1.3,1.4,1.7,1.5,1.7,1.5,1.0,1.7,1.9,1.6,1.6,1.5,1.4,1.6,1.6,1.5,1.5,1.4,1.5,1.2,1.3,1.5,1.3,1.5,1.3,1.3,1.3,1.6,1.9,1.4,1.6,1.4,1.5,1.4],"sizemode":"area","sizeref":0.01725,"symbol":"circle"},"mode":"markers","name":"setosa","orientation":"v","showlegend":true,"x":[3.5,3.0,3.2,3.1,3.6,3.9,3.4,3.4,2.9,3.1,3.7,3.4,3.0,3.0,4.0,4.4,3.9,3.5,3.8,3.8,3.4,3.7,3.6,3.3,3.4,3.0,3.4,3.5,3.4,3.2,3.1,3.4,4.1,4.2,3.1,3.2,3.5,3.1,3.0,3.4,3.5,2.3,3.2,3.5,3.8,3.0,3.8,3.2,3.7,3.3],"xaxis":"x","y":[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9,5.4,4.8,4.8,4.3,5.8,5.7,5.4,5.1,5.7,5.1,5.4,5.1,4.6,5.1,4.8,5.0,5.0,5.2,5.2,4.7,4.8,5.4,5.2,5.5,4.9,5.0,5.5,4.9,4.4,5.1,5.0,4.5,4.4,5.0,5.1,4.8,5.1,4.6,5.3,5.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"species=versicolor\u003cbr\u003esepal_width=%{x}\u003cbr\u003esepal_length=%{y}\u003cbr\u003epetal_length=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"versicolor","marker":{"color":"#EF553B","size":[4.7,4.5,4.9,4.0,4.6,4.5,4.7,3.3,4.6,3.9,3.5,4.2,4.0,4.7,3.6,4.4,4.5,4.1,4.5,3.9,4.8,4.0,4.9,4.7,4.3,4.4,4.8,5.0,4.5,3.5,3.8,3.7,3.9,5.1,4.5,4.5,4.7,4.4,4.1,4.0,4.4,4.6,4.0,3.3,4.2,4.2,4.2,4.3,3.0,4.1],"sizemode":"area","sizeref":0.01725,"symbol":"circle"},"mode":"markers","name":"versicolor","orientation":"v","showlegend":true,"x":[3.2,3.2,3.1,2.3,2.8,2.8,3.3,2.4,2.9,2.7,2.0,3.0,2.2,2.9,2.9,3.1,3.0,2.7,2.2,2.5,3.2,2.8,2.5,2.8,2.9,3.0,2.8,3.0,2.9,2.6,2.4,2.4,2.7,2.7,3.0,3.4,3.1,2.3,3.0,2.5,2.6,3.0,2.6,2.3,2.7,3.0,2.9,2.9,2.5,2.8],"xaxis":"x","y":[7.0,6.4,6.9,5.5,6.5,5.7,6.3,4.9,6.6,5.2,5.0,5.9,6.0,6.1,5.6,6.7,5.6,5.8,6.2,5.6,5.9,6.1,6.3,6.1,6.4,6.6,6.8,6.7,6.0,5.7,5.5,5.5,5.8,6.0,5.4,6.0,6.7,6.3,5.6,5.5,5.5,6.1,5.8,5.0,5.6,5.7,5.7,6.2,5.1,5.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"species=virginica\u003cbr\u003esepal_width=%{x}\u003cbr\u003esepal_length=%{y}\u003cbr\u003epetal_length=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"virginica","marker":{"color":"#00cc96","size":[6.0,5.1,5.9,5.6,5.8,6.6,4.5,6.3,5.8,6.1,5.1,5.3,5.5,5.0,5.1,5.3,5.5,6.7,6.9,5.0,5.7,4.9,6.7,4.9,5.7,6.0,4.8,4.9,5.6,5.8,6.1,6.4,5.6,5.1,5.6,6.1,5.6,5.5,4.8,5.4,5.6,5.1,5.1,5.9,5.7,5.2,5.0,5.2,5.4,5.1],"sizemode":"area","sizeref":0.01725,"symbol":"circle"},"mode":"markers","name":"virginica","orientation":"v","showlegend":true,"x":[3.3,2.7,3.0,2.9,3.0,3.0,2.5,2.9,2.5,3.6,3.2,2.7,3.0,2.5,2.8,3.2,3.0,3.8,2.6,2.2,3.2,2.8,2.8,2.7,3.3,3.2,2.8,3.0,2.8,3.0,2.8,3.8,2.8,2.8,2.6,3.0,3.4,3.1,3.0,3.1,3.1,3.1,2.7,3.2,3.3,3.0,2.5,3.0,3.4,3.0],"xaxis":"x","y":[6.3,5.8,7.1,6.3,6.5,7.6,4.9,7.3,6.7,7.2,6.5,6.4,6.8,5.7,5.8,6.4,6.5,7.7,7.7,6.0,6.9,5.6,7.7,6.3,6.7,7.2,6.2,6.1,6.4,7.2,7.4,7.9,6.4,6.3,6.1,7.7,6.3,6.4,6.0,6.9,6.7,6.9,5.8,6.8,6.7,6.7,6.3,6.5,6.2,5.9],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888," ...

# %% [markdown]
# ## Table with Pandas

# %%
#| echo: true
#| output: false
import pandas as pd
from IPython.display import HTML
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Score": [85, 92, 78]
}

df = pd.DataFrame(data)
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alice</td>
#       <td>85</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Bob</td>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Charlie</td>
#       <td>78</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Without code:**

# %%
#| echo: false
#| output: true

import pandas as pd
from IPython.display import HTML
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Score": [85, 92, 78]
}

df = pd.DataFrame(data)
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alice</td>
#       <td>85</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Bob</td>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Charlie</td>
#       <td>78</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Highlighting certain cells in Pandas

# %%
import pandas as pd
import numpy as np

np.random.seed(0)
df2 = pd.DataFrame(np.random.randn(10,4), columns=['A','B','C','D'])

def style_negative(v, props=''):
    return props if v < 0 else None
s2 = df2.style.map(style_negative, props='color:red;')\
              .map(lambda v: 'opacity: 20%;' if (v < 0.3) and (v > -0.3) else None)

def highlight_max(s, props=''):
    return np.where(s == np.nanmax(s.values), props, '')

# darkblue, pink
s2.apply(highlight_max, props='color:white;background-color:#00008b', axis=0)\
.apply(highlight_max, props='color:white;background-color: #ffc0cb;', axis=1)\
.apply(highlight_max, props='color:white;background-color:purple', axis=None)
# Out:
# <style type="text/css">
# #T_999c9_row0_col2, #T_999c9_row7_col1 {
#   color: white;
#   background-color: #00008b;
# }
# #T_999c9_row0_col3 {
#   color: white;
#   background-color: #00008b;
#   color: white;
#   background-color: #ffc0cb;
# }
# #T_999c9_row1_col0, #T_999c9_row2_col3, #T_999c9_row3_col0, #T_999c9_row4_col0, #T_999c9_row5_col2, #T_999c9_row7_col0, #T_999c9_row9_col0 {
#   color: white;
#   background-color: #ffc0cb;
# }
# #T_999c9_row1_col1, #T_999c9_row4_col3, #T_999c9_row5_col0, #T_999c9_row5_col3, #T_999c9_row6_col1, #T_999c9_row8_col0, #T_999c9_row8_col1, #T_999c9_row8_col2, #T_999c9_row9_col2, #T_999c9_row9_col3 {
#   color: red;
# }
# #T_999c9_row1_col3, #T_999c9_row2_col0, #T_999c9_row4_col1, #T_999c9_row6_col3 {
#   color: red;
#   opacity: 20%;
# }
# #T_999c9_row2_col2, #T_999c9_row3_col1, #T_999c9_row6_col2, #T_999c9_row7_col2 {
#   opacity: 20%;
# }
# #T_999c9_row6_col0 {
#   color: white;
#   background-color: #00008b;
#   color: white;
#   background-color: #ffc0cb;
#   color: white;
#   background-color: purple;
# }
# #T_999c9_row8_col3 {
#   opacity: 20%;
#   color: white;
#   background-color: #ffc0cb;
# }
# </style>
# <table id="T_999c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_999c9_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_999c9_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_999c9_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_999c9_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_999c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_999c9_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_999c9_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_999c9_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_999c9_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_999c9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_999c9_row1_col0" class="data row1 col0" >1.867558</td>
#       <td id="T_999c9_row1_col1" class="data row1 col1" >-0.977278</td>
#       <td id="T_999c9_row1_col2" class="data row1 col2" >0.950088</td>
#       <td id="T_999c9_row1_col3" class="data row1 col3" >-0.151357</td>
#     </tr>
#     <tr>
#       <th id="T_999c9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_999c9_row2_col0" class="data row2 col0" >-0.103219</td>
#       <td id="T_999c9_row2_col1" class="data row2 col1" >0.410599</td>
#       <td id="T_999c9_row2_col2" class="data row2 col2" >0.144044</td>
#       <td id="T_999c9_row2_col3" class="data row2 col3" >1.454274</td>
#     </tr>
#     <tr>
#       <th id="T_999c9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_999c9_row3_col0" class="data row3 col0" >0.761038</td>
#       <td id="T_999c9_row3_col1" class="data row3 col1" >0.121675</td>
#       <td id="T_999c9_row3_col2" class="data row3 col2" >0.443863</td>
#       <td id="T_999c9_row3_col3" class="data row3 col3" >0.333674</td>
#     </tr>
#     <tr>
#       <th id="T_999c9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_999c9_row4_col0" class="data row4 col0" >1.494079</td>
#       <td id="T_999c9_row4_col1" class="data row4 col1" >-0.205158</td>
#       <td id="T_999c9_row4_col2" class="data row4 col2" >0.313068</td>
#       <td id="T_999c9_row4_col3" class="data row4 col3" >-0.854096</td>
#     </tr>
#     <tr>
#       <th id="T_999c9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_999c9_row5_col0" class="data row5 col0" >-2.552990</td>
#       <td id="T_999c9_row5_col1" class="data row5 col1" >0.653619</td>
#       <td id="T_999c9_row5_col2" class="data row5 col2" >0.864436</td>
#       <td id="T_999c9_row5_col3" class="data row5 col3" >-0.742165</td>
#     </tr>
#     <tr>
#       <th id="T_999c9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_999c9_row6_col0" class="data row6 col0" >2.269755</td>
#       <td id="T_999c9_row6_col1" class="data row6 col1" >-1.454366</td>
#       <td id="T_999c9_row6_col2" class="data row6 col2" >0.045759</td>
#       <td id="T_999c9_row6_col3" class="data row6 col3" >-0.187184</td>
#     </tr>
#     <tr>
#       <th id="T_999c9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_999c9_row7_col0" class="data row7 col0" >1.532779</td>
#       <td id="T_999c9_row7_col1" class="data row7 col1" >1.469359</td>
#       <td id="T_999c9_row7_col2" class="data row7 col2" >0.154947</td>
#       <td id="T_999c9_row7_col3" class="data row7 col3" >0.378163</td>
#     </tr>
#     <tr>
#       <th id="T_999c9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_999c9_row8_col0" class="data row8 col0" >-0.887786</td>
#       <td id="T_999c9_row8_col1" class="data row8 col1" >-1.980796</td>
#       <td id="T_999c9_row8_col2" class="data row8 col2" >-0.347912</td>
#       <td id="T_999c9_row8_col3" class="data row8 col3" >0.156349</td>
#     </tr>
#     <tr>
#       <th id="T_999c9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_999c9_row9_col0" class="data row9 col0" >1.230291</td>
#       <td id="T_999c9_row9_col1" class="data row9 col1" >1.202380</td>
#       <td id="T_999c9_row9_col2" class="data row9 col2" >-0.387327</td>
#       <td id="T_999c9_row9_col3" class="data row9 col3" >-0.302303</td>
#     </tr>
#   </tbody>
# </table>
